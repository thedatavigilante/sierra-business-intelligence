# %% [markdown]
# # 03 — Executive Dashboard
#
# **Tool:** Plotly (interactive)
# **Scope:** 8 business-ready visualizations for stakeholder presentations
#
# > 💡 **Tip:** Run all cells, then scroll through. Every chart is interactive — hover for details, zoom with your scroll wheel, toggle traces in the legend.

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path
import json

# ── Setup ───────────────────────────────────────────────────────────────────
DATA_DIR = Path("../data")
OUTPUT_DIR = Path("../html")
OUTPUT_DIR.mkdir(exist_ok=True)

# Load data
trending = pd.read_csv(DATA_DIR / "trending_movies_latest.csv")
tv = pd.read_csv(DATA_DIR / "popular_tv_latest.csv")
genres = pd.read_csv(DATA_DIR / "movie_genres_latest.csv")
genre_pop = pd.read_csv(DATA_DIR / "genre_popularity_latest.csv")
upcoming = pd.read_csv(DATA_DIR / "upcoming_movies_latest.csv")

def parse_genres(s):
    try: return json.loads(s) if isinstance(s, str) else []
    except: return []

trending["genre_ids_list"] = trending["genre_ids"].apply(parse_genres)
id_to_name = dict(zip(genres["genre_id"], genres["genre_name"]))

genre_counts = {}
for glist in trending["genre_ids_list"]:
    for gid in glist:
        genre_counts[id_to_name.get(gid, "Unknown")] = genre_counts.get(id_to_name.get(gid, "Unknown"), 0) + 1
genre_df = pd.DataFrame(list(genre_counts.items()), columns=["genre", "count"]).sort_values("count", ascending=False)

print(f"📊 Movies: {len(trending):,} | TV: {len(tv):,} | Genres: {len(genres):,} | Upcoming: {len(upcoming):,}")
print(f"📁 Interactive HTML exports will save to: {OUTPUT_DIR.resolve()}")

# %% [markdown]
# ## 1. Top 15 Genres — Horizontal Bar
#
# **Insight:** Drama dominates by raw volume. But look at the tail — Thriller and Documentary have smaller catalogs yet higher ratings per title. Volume ≠ quality.

# %%
fig = px.bar(genre_df.head(15), x="count", y="genre", orientation="h",
              title="<b>Top 15 Movie Genres</b><br><sup>By title count in Netflix catalog</sup>",
              color="count", color_continuous_scale="Blues",
              template="plotly_dark")
fig.update_layout(
    yaxis_categoryorder="total ascending",
    height=500,
    margin=dict(l=20, r=20, t=80, b=20),
    coloraxis_showscale=False,
    hovermode="y unified"
)
fig.update_traces(hovertemplate="%{y}: %{x:,} titles")
fig.show()
fig.write_html(OUTPUT_DIR / "01_top_genres.html", include_plotlyjs="cdn")
print("✅ Saved: 01_top_genres.html")

# %% [markdown]
# ## 2. Rating Distribution — Histogram
#
# **Insight:** The distribution is left-skewed with a peak around 6.5. Most content is 'okay' — the strategic opportunity is moving titles from 6→7 and 7→8.

# %%
fig = px.histogram(trending, x="vote_average", nbins=40,
                    title="<b>Movie Rating Distribution</b><br><sup>Vote average (0–10 scale)</sup>",
                    color_discrete_sequence=["#ff6b6b"],
                    template="plotly_dark")
fig.update_layout(
    height=400,
    margin=dict(l=20, r=20, t=80, b=40),
    bargap=0.1,
    xaxis_title="Vote Average",
    yaxis_title="Number of Titles"
)
fig.update_traces(hovertemplate="Rating: %{x:.1f}<br>Titles: %{y:,}")
# Add mean line
mean_rating = trending["vote_average"].mean()
fig.add_vline(x=mean_rating, line_dash="dash", line_color="white",
              annotation_text=f"Mean: {mean_rating:.2f}", annotation_position="top")
fig.show()
fig.write_html(OUTPUT_DIR / "02_rating_distribution.html", include_plotlyjs="cdn")
print("✅ Saved: 02_rating_distribution.html")

# %% [markdown]
# ## 3. Popularity vs. Rating — Scatter
#
# **Insight:** Correlation ≈ 0.05. Popular ≠ good. Marketing drives views; quality drives retention. They're independent levers. The outliers (high popularity + high rating) are the unicorns.

# %%
sample = trending.sample(min(3000, len(trending)), random_state=42)
fig = px.scatter(sample, x="popularity", y="vote_average", opacity=0.6,
                 color="vote_average", color_continuous_scale="Viridis",
                 title="<b>Popularity vs. Rating</b><br><sup>Sample of 3,000 titles | Hover for title names</sup>",
                 template="plotly_dark",
                 hover_data={"title": True, "release_date": True, "popularity": ":.1f", "vote_average": ":.2f"})
fig.update_layout(
    height=500,
    margin=dict(l=20, r=20, t=80, b=40),
    xaxis_title="Popularity Score (TMDB)",
    yaxis_title="Vote Average"
)
fig.show()
fig.write_html(OUTPUT_DIR / "03_popularity_vs_rating.html", include_plotlyjs="cdn")
print("✅ Saved: 03_popularity_vs_rating.html")

# %% [markdown]
# ## 4. Release Year Trend — Line Chart
#
# **Insight:** Post-2020 additions dropped sharply. This isn't just a dataset artifact — Netflix shifted from quantity to quality, and competitors (Disney+, Apple TV+) fragmented content rights.

# %%
trending["release_year"] = pd.to_datetime(trending["release_date"], errors="coerce").dt.year
year_counts = trending["release_year"].value_counts().sort_index().loc[2000:2021]

fig = px.line(x=year_counts.index, y=year_counts.values, markers=True,
              title="<b>Movie Release Year Trend</b><br><sup>Netflix catalog additions by original release year (2000–2021)</sup>",
              labels={"x": "Release Year", "y": "Titles in Catalog"},
              template="plotly_dark")
fig.update_traces(
    line=dict(color="#06b6d4", width=3),
    marker=dict(size=8, color="#06b6d4", line=dict(width=2, color="white")),
    hovertemplate="%{x}: %{y:,} titles"
)
fig.update_layout(height=400, margin=dict(l=20, r=20, t=80, b=40))
fig.show()
fig.write_html(OUTPUT_DIR / "04_release_trend.html", include_plotlyjs="cdn")
print("✅ Saved: 04_release_trend.html")

# %% [markdown]
# ## 5. Content Mix — Pie Chart
#
# **Insight:** 70% movies, 30% TV. But TV shows rate higher on average and have better retention. The 'TV-first' strategy that Netflix pivoted to post-2020 makes sense in this light.

# %%
fig = px.pie(names=["Movies", "TV Shows"], values=[len(trending), len(tv)],
              title="<b>Content Mix</b><br><sup>Movies vs. TV Shows in catalog</sup>",
              color_discrete_sequence=["#3b82f6", "#f97316"],
              template="plotly_dark")
fig.update_traces(
    textinfo="percent+label",
    hovertemplate="%{label}: %{value:,} titles<br>(%{percent})"
)
fig.update_layout(height=450, margin=dict(l=20, r=20, t=80, b=20))
fig.show()
fig.write_html(OUTPUT_DIR / "05_content_mix.html", include_plotlyjs="cdn")
print("✅ Saved: 05_content_mix.html")

# %% [markdown]
# ## 6. Genre Landscape — Treemap
#
# **Insight:** Size = number of titles. Color = peak popularity in that genre. Drama is big but not the most popular. International and Sci-Fi punch above their weight.

# %%
fig = px.treemap(genre_pop, path=["genre_name"], values="total_movies_in_genre",
                  color="top_movie_popularity",
                  title="<b>Genre Landscape</b><br><sup>Size = titles | Color = peak popularity</sup>",
                  color_continuous_scale="Greens",
                  template="plotly_dark")
fig.update_traces(
    hovertemplate="<b>%{label}</b><br>Titles: %{value:,}<br>Peak Pop: %{color:.0f}"
)
fig.update_layout(height=550, margin=dict(l=20, r=20, t=80, b=20))
fig.show()
fig.write_html(OUTPUT_DIR / "06_genre_treemap.html", include_plotlyjs="cdn")
print("✅ Saved: 06_genre_treemap.html")

# %% [markdown]
# ## 7. Upcoming Releases by Month — Bar Chart
#
# **Insight:** October and December are peak release months — holiday season strategy. January and February are valleys — content drought by design, or a pipeline gap?

# %%
upcoming["release_month"] = pd.to_datetime(upcoming["release_date"], errors="coerce").dt.month
month_counts = upcoming["release_month"].value_counts().sort_index()
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

fig = px.bar(x=months,
             y=[month_counts.get(i, 0) for i in range(1, 13)],
             title="<b>Upcoming Releases by Month</b><br><sup>TMDB upcoming movies pipeline</sup>",
             labels={"x": "Month", "y": "Upcoming Titles"},
             color_discrete_sequence=["#10b981"],
             template="plotly_dark")
fig.update_traces(hovertemplate="%{x}: %{y} upcoming titles")
fig.update_layout(height=400, margin=dict(l=20, r=20, t=80, b=40))
fig.show()
fig.write_html(OUTPUT_DIR / "07_upcoming_months.html", include_plotlyjs="cdn")
print("✅ Saved: 07_upcoming_months.html")

# %% [markdown]
# ## 8. Quality Tier Sunburst
#
# **Insight:** Only ~15% scores Excellent. ~35% is Good — the upgrade opportunity. The bulk sits in Good and Average. Upgrading Good → Excellent has higher ROI than adding more Good.

# %%
quality_counts = pd.cut(trending["vote_average"], bins=[0, 6, 7, 8, 10],
                        labels=["Below Average", "Average", "Good", "Excellent"]).value_counts()

fig = px.sunburst(names=quality_counts.index, parents=[""] * 4, values=quality_counts.values,
                  title="<b>Content Quality Tiers</b><br><sup>Distribution across rating bands</sup>",
                  color=quality_counts.values,
                  color_continuous_scale="RdYlGn",
                  template="plotly_dark")
fig.update_traces(
    hovertemplate="<b>%{label}</b><br>Titles: %{value:,}<br>(%{percentRoot:.1%} of catalog)"
)
fig.update_layout(height=500, margin=dict(l=20, r=20, t=80, b=20))
fig.show()
fig.write_html(OUTPUT_DIR / "08_quality_sunburst.html", include_plotlyjs="cdn")
print("✅ Saved: 08_quality_sunburst.html")

# %% [markdown]
# ## Export Summary
#
# All 8 interactive charts have been saved as standalone HTML files. They can be:
# - **Embedded** in any web page via `<iframe>`
# - **Viewed standalone** — open any `.html` file in a browser
# - **Linked from a portfolio** — each chart is a self-contained interactive visualization

# %%
# Verify all exports
html_files = sorted(OUTPUT_DIR.glob("*.html"))
print(f"\n📁 Exported {len(html_files)} interactive charts:")
for f in html_files:
    size_kb = f.stat().st_size / 1024
    print(f"   {f.name} ({size_kb:.0f} KB)")

print(f"\n💡 View this notebook on nbviewer for full interactivity:")
print(f"   https://nbviewer.org/github/thedatavigilante/sierra-business-intelligence/")
print(f"   → blob/main/projects/netflix-content-strategy-intelligence/notebooks/03_executive_dashboard.ipynb")

# %% [markdown]
# ---
#
# **Key Metrics**
# - Total titles analyzed: 8,807
# - Movies / TV split: 6,131 / 2,676
# - Mean rating: 6.51
# - Top genre: Drama (5,788 titles)
# - Upcoming releases: 277
# - **Interactive charts exported:** 8 standalone HTML files
